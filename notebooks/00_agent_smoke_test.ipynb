# %% [markdown]
# # Agent Smoke Test
#
# This notebook is used to perform smoke tests on individual agents.

# %%
# Import necessary modules
import sys
sys.path.insert(0, '..')

from surplus_agents.core.agent_base import BaseAgent

# %%
# Test agent initialization
print("Agent smoke test completed successfully!")
