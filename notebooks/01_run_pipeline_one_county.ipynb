# %% [markdown]
# # Run Pipeline - One County
#
# This notebook demonstrates running the surplus pipeline for a single county.

# %%
# Import necessary modules
import sys
sys.path.insert(0, '..')

from surplus_agents.pipelines.surplus_pipeline import *

# %%
# Run pipeline for one county
print("Pipeline execution placeholder")
